# %% [markdown]
# <a href="https://colab.research.google.com/github/Py7949/Data-Science-/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Series**
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# Importing Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Series from lists**

# %%
#string

country = [ 'India','Pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# Integer
runs = [100,200,300,400,500]
run_series = pd.Series(runs)
run_series
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
# custom index
marks = [10,20,30,40,50]
subjects = ['Englis','Maths','Science','Social','Hindi']
pd.Series(marks,index = subjects)
# Out:
# Englis     10
# Maths      20
# Science    30
# Social     40
# Hindi      50
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index = subjects,name = 'pankaj ke marks')
marks
# Out:
# Englis     10
# Maths      20
# Science    30
# Social     40
# Hindi      50
# Name: pankaj ke marks, dtype: int64

# %% [markdown]
# **Series from dict**

# %%
marks = {'Englis':10,'Maths':20,'Science':30,'Social':40,'Hindi':50}
marks_series = pd.Series(marks,name = 'pankaj ke marks')
marks_series
# Out:
# Englis     10
# Maths      20
# Science    30
# Social     40
# Hindi      50
# Name: pankaj ke marks, dtype: int64

# %% [markdown]
# **Series Attribute**

# %%
#size
marks_series.size
# Out:
# 5

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'pankaj ke marks'

# %%
# is_unique
marks_series.is_unique
# Out:
# True

# %%
# index
marks_series.index
# Out:
# Index(['Englis', 'Maths', 'Science', 'Social', 'Hindi'], dtype='object')

# %%
run_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# **Series using read_csv**

# %%
#with one col
subs = pd.read_csv('/content/subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# with 2 col

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
bd=pd.read_csv('/content/bollywood.csv',index_col='movie')
bd
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# ** Series methods**

# %%
#head and tail
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
vk.head(3)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13

# %%
subs.tail()
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
bd.tail(2)
# Out:
#                               lead
# movie
# Company (film)          Ajay Devgn
# Awara Paagal Deewana  Akshay Kumar

# %%
#sample
subs.sample()
# Out:
#      Subscribers gained
# 126                  64

# %%
vk.sample()
# Out:
#           runs
# match_no
# 30          38

# %%
bd.sample(5)
# Out:
#                                      lead
# movie
# Bangistan            Jacqueline Fernandez
# Jhoom Barabar Jhoom     Abhishek Bachchan
# A Gentleman             Sidharth Malhotra
# Rajma Chawal                 Amyra Dastur
# Shamitabh                Amitabh Bachchan

# %%
# value_count -> movies
bd.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
#sort_values -> inplace
vk.sort_values(by='runs',ascending=False).head(1).values[0]
vk
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
#sort_index -> inplace ->movies
vk.sort_values(by='runs',inplace=True)
vk
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
#sort_index -> inplace ->bd
bd.sort_index(inplace=True)
bd
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# Series Maths Methods
# **bold text**

# %%
# Count
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
# sum -> product
subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
# mean -> median -> mode -> std -> -> var
vk.mean()
# Out:
# runs    30.855814
# dtype: float64

# %%
subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
vk.median()
# Out:
# runs    24.0
# dtype: float64

# %%
bd.mode()
# Out:
#            lead
# 0  Akshay Kumar

# %%
subs.std()
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
vk.var()
# Out:
# runs    688.002478
# dtype: float64

# %%
#min/max
vk.min()
# Out:
# runs    0
# dtype: int64

# %%
subs.max()
# Out:
# Subscribers gained    396
# dtype: int64

# %%
# describe
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %% [markdown]
# **Series Indexing**

# %%
# integer indexing
x = pd.Series([12,13,14,15,16,34,6,45,])
x[1]
# Out:
# np.int64(13)

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# 5    34
# 6     6
# 7    45
# dtype: int64

# %%
# negative indexing
x[-1]   #negative indexing doesn't work in pandas but negative work when index are string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-60055cb99cf0> in <cell line: 0>()
#       1 # negative indexing
# ----> 2 x[-1]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
vk
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
marks_series[-1]
# Out:
# <ipython-input-99-14301c43e6a1>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   marks_series[-1]
# np.int64(50)

# %%
# slicing
vk[5:16]
# Out:
#           runs
# match_no
# 207          0
# 135          0
# 130          0
# 211          0
# 106          1
# 204          1
# 113          1
# 77           1
# 1            1
# 5            1
# 75           1

# %%
vk[-5:]
# Out:
#           runs
# match_no
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113

# %%
bd[::2]
# Out:
#                                       lead
# movie
# 1920 (film)               Rajniesh Duggall
# 1920: The Evil Returns         Vicky Ahuja
# 2 States (2014 film)          Arjun Kapoor
# 3 A.M. (2014 film)           Salil Acharya
# 3 Idiots                        Aamir Khan
# ...                                    ...
# Zero (2018 film)            Shah Rukh Khan
# Zila Ghaziabad                Vivek Oberoi
# Zindaggi Rocks                Sushmita Sen
# Zindagi Na Milegi Dobara    Hrithik Roshan
# Zokkomon                   Darsheel Safary
#
# [750 rows x 1 columns]

# %%
#fancy indexing
vk.loc[[1,3,4,5]]
# Out:
#           runs
# match_no
# 1            1
# 3           13
# 4           12
# 5            1

# %%
# indexing with labels -> fancy indexing
print(bd.index)
# Out:
# Index(['1920 (film)', '1920: London', '1920: The Evil Returns',
#        '1971 (2007 film)', '2 States (2014 film)', '22 Yards',
#        '3 A.M. (2014 film)', '3 Deewarein', '3 Idiots', '3 Storeys',
#        ...
#        'Zero (2018 film)', 'Zid (2014 film)', 'Zila Ghaziabad', 'Zinda (film)',
#        'Zindaggi Rocks', 'Zindagi 50-50', 'Zindagi Na Milegi Dobara',
#        'Zindagi Tere Naam', 'Zokkomon', 'Zor Lagaa Ke...Haiya!'],
#       dtype='object', name='movie', length=1500)

# %%
bd.index.get_loc('2 States (2014 film)')
# Out:
# 4

# %% [markdown]
# **Editing Series**

# %%
#using indexing
marks_series[2]=100
marks_series
# Out:
# <ipython-input-100-4340d24ae805>:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[2]=100
# Englis      10
# Maths      100
# Science    100
# Social      40
# Hindi       50
# Name: pankaj ke marks, dtype: int64

# %%
# what if an index doesn't exist
marks_series['sst'] = 90

# %%
marks_series
# Out:
# Englis      10
# Maths      100
# Science    100
# Social      40
# Hindi       50
# sst         90
# Name: pankaj ke marks, dtype: int64

# %%
# Slicing
run_series[2:4] = [100,100]
run_series
# Out:
# 0    100
# 1    200
# 2    100
# 3    100
# 4    500
# dtype: int64

# %%
#fancy indexing
run_series[[0,3,4]] = [0,0,0]
run_series
# Out:
# 0      0
# 1    200
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
bd.index.get_loc('2 States (2014 film)') == 'ALia Bhatt'
bd
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# **Series with Python Functionalities**

# %%
# len /type / dir / sorted /max / min
print(len(subs))
# Out:
# 365

# %%
print(type(subs))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(dir(subs))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__'
# ...

# %%
print(sorted(subs))
# Out:
# ['Subscribers gained']

# %%
print(max(bd))
# Out:
# lead

# %%
print(min(bd))
# Out:
# lead

# %%
bd.min()
# Out:
# lead    Aadar Jain
# dtype: object

# %%
bd.max()
# Out:
# lead    Zulfi Sayed
# dtype: object

# %%
#type conversion
list(marks_series)
# Out:
# [10, 100, 100, 40, 50, 90]

# %%
dict(marks_series)
# Out:
# {'Englis': np.int64(10),
#  'Maths': np.int64(100),
#  'Science': np.int64(100),
#  'Social': np.int64(40),
#  'Hindi': np.int64(50),
#  'sst': np.int64(90)}

# %%
#membership operator

'Zor Lagaa Ke...Haiya!' not in bd
# Out:
# True

# %%
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %%
#Arithmatic operator (Broadcasting)
100 - marks_series
# Out:
# Englis     90
# Maths       0
# Science     0
# Social     60
# Hindi      50
# sst        10
# Name: pankaj ke marks, dtype: int64

# %%
# Relational Operator
vk >= 50
# Out:
#            runs
# match_no
# 8         False
# 87        False
# 93        False
# 91        False
# 206       False
# ...         ...
# 164        True
# 120        True
# 123        True
# 126        True
# 128        True
#
# [215 rows x 1 columns]

# %% [markdown]
# **Boolean indexing on series**

# %%
# Find no of 50s and 100's scored by Kohli
vk[vk >= 50].count()
# Out:
# runs    50
# dtype: int64

# %%
#find no of ducks
vk[vk == 0].count()
# Out:
# runs    9
# dtype: int64

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].count()
# Out:
# Subscribers gained    59
# dtype: int64

# %%
# find actors who have done more than 20 mvies
num_movies = bd.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# **Plotting Graphs on series**

# %%
subs.plot()
# Out:
# <Axes: >

# %%
bd.value_counts().head(20).plot(kind = 'bar')
# Out:
# <Axes: xlabel='lead'>

# %%
bd.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Some Important Series** **Methods**

# %%
 # astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# 3472

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 2182

# %%
# between
vk['runs'][vk['runs'].between(51,99)].size
# Out:
# 43

# %%
# clip
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.clip(100,200)
# Out:
#      Subscribers gained
# 0                   100
# 1                   100
# 2                   100
# 3                   100
# 4                   100
# ..                  ...
# 360                 200
# 361                 200
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
bd.drop_duplicates()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Sssshhh...                            Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                Tanuja
# Right Here Right Now (film)                      Ankit
# Talaash: The Hunt Begins...              Rakhee Gulzar
# The Pink Mirror                        Edwin Fernandes
#
# [566 rows x 1 columns]

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
# isnull
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk[(vk == 49) | (vk == 99)]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
vk[vk.isin([49,99])]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
# apply
bd
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
bd['lead'].apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
subs['Subscribers gained'].apply(lambda x:'good day' if x > subs.mean().values[0] else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
# copy

# %%
new = vk.head()

# %%
new
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
